# %% [markdown]
# # Import libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Payoff matrices for Player A and Player B
payoffs = {
    "A": np.array([[3, 0], [5, 1]]), 
    "B": np.array([[3, 5], [0, 1]])
}

# %%
# Q-tables for both players
Q_A = np.zeros((2, 2))  
Q_B = np.zeros((2, 2))

# %%
# Q-learning parameters
alpha = 0.5  # Learning rate
gamma_A = 0.9  # Discount factor
gamma_B = 0.9  # Discount factor
epsilon = 0.8  # Exploration rate
min_epsilon = 0.01  # Minimum exploration rate
decay_rate = 0.000001  # Decay rate for epsilon

# Simulation parameters
episodes = 1000
# Initial state (i.e. inital rival's choice)
state_A = np.random.choice([0, 1])
state_B = np.random.choice([0, 1])

# %%
# Track simulations result regarding cooperation rates
track_cooperation = []  
coop_A_count = 0
coop_B_count = 0

# %%
# Helper function for epsilon-greedy action selection
def choose_action(Q_column, epsilon):
    if np.random.rand() < epsilon:
        # Random action (exploration)
        print('Exploring')
        return np.random.choice([0, 1])  # 0 = "C", 1 = "D"
    else:
        # Greedy action (exploitation)
        max_actions = np.flatnonzero(Q_column == Q_column.max())
        randomChoice = np.random.choice(max_actions)
        return randomChoice

# %%
# Epsilon decay function
def epsilon_decay(epsilon, min_epsilon, decay_rate, episode):
    return max(min_epsilon, epsilon * np.exp(-decay_rate * episode))

# %%
# Run Q-learning
for episode in range(1, episodes + 1):
    # Decay epsilon
    epsilon = epsilon_decay(epsilon, min_epsilon, decay_rate, episode)
    print('Epsilon = ', epsilon, ', and episode is :', episode)
    
    # Choose actions
    action_A = choose_action(Q_A[:,state_A], epsilon)
    action_B = choose_action(Q_B[:,state_B], epsilon)

    # Count cooperation
    if action_A == 0:  
        coop_A_count += 1
    if action_B == 0:
        coop_B_count += 1
    
    # Get rewards
    reward_A = payoffs["A"][action_A, action_B]
    reward_B = payoffs["B"][action_A, action_B]
    
    
    # Update Q-tables
    Q_A[action_A, action_B] += alpha * (reward_A + gamma_A * np.max(Q_A[:, action_B]) - Q_A[action_A, action_B])
    Q_B[action_B, action_A] += alpha * (reward_B + gamma_B * np.max(Q_B[:,action_A]) - Q_B[action_B, action_A])
    
     # Update next state
    state_A = action_B 
    state_B = action_A
    
    # Track cooperation every 100 episodes
    if episode % 100 == 0:
        track_cooperation.append({
            "episode": episode,
            "cooperation_A": coop_A_count / 100,
            "cooperation_B": coop_B_count / 100
        })
        coop_A_count = 0
        coop_B_count = 0
# Out:
# Epsilon =  0.7999992000004 , and episode is : 1
# Exploring
# Exploring
# Epsilon =  0.7999976000036 , and episode is : 2
# Exploring
# Exploring
# Epsilon =  0.7999952000143999 , and episode is : 3
# Exploring
# Epsilon =  0.7999920000399999 , and episode is : 4
# Exploring
# Exploring
# Epsilon =  0.7999880000899996 , and episode is : 5
# Exploring
# Epsilon =  0.7999832001763988 , and episode is : 6
# Exploring
# Epsilon =  0.7999776003135971 , and episode is : 7
# Exploring
# Exploring
# Epsilon =  0.7999712005183939 , and episode is : 8
# Exploring
# Exploring
# Epsilon =  0.799964000809988 , and episode is : 9
# Exploring
# Exploring
# Epsilon =  0.7999560012099779 , and episode is : 10
# Exploring
# Epsilon =  0.7999472017423617 , and episode is : 11
# Exploring
# Exploring
# Epsilon =  0.7999376024335367 , and episode is : 12
# Exploring
# Exploring
# Epsilon =  0.7999272033122995 , and episode is : 13
# Exploring
# Epsilon =  0.7999160044098457 , and episode is : 14
# Exploring
# Epsilon =  0.7999040057597696 , and episode is : 15
# Exploring
# Epsilon =  0.7998912073980646 , and episode is : 16
# Exploring
# Exploring
# Epsilon =  0.7998776093631225 , and episode is : 17
# Exploring
# Exploring
# Epsilon =  0.7998632116957333 , and episode is : 18
# Exploring
# Exploring
# Epsilon =  0.7998480144390855 , and episode is : 19
# Exploring
# Exploring
# Epsilon =  0.7998320176387652 , and episode is : 20
# Exploring
# Exploring
# Epsilon =  0.7998152213427565 , and episode is : 21
# Epsilon =  0.7997976256014409 , and episode is : 22
# Exploring
# Exploring
# Epsilon =  0.7997792304675969 , and episode is : 23
# Exploring
# Epsilon =  0.7997600359964003 , and episode is : 24
# Exploring
# Exploring
# Epsilon =  0.7997400422454234 , and episode is : 25
# Exploring
# Epsilon =  0.7997192492746348 , and episode is : 26
# Exploring
# Epsilon =  0.7996976571463994 , and episode is : 27
# Exploring
# Exploring
# Epsilon =  0.7996752659254778 , and episode is : 28
# Exploring
# Exploring
# Epsilon =  0.7996520756790261 , and episode is : 29
# Exploring
# Epsilon =  0.7996280864765956 , and episode is : 30
# Exploring
# Exploring
# Epsilon =  0.7996032983901321 , and episode is : 31
# Exploring
# Epsilon =  0.7995777114939762 , and episode is : 32
# Exploring
# Exploring
# Epsilon =  0.7995513258648622 , and episode is : 33
# Exploring
# Exploring
# Epsilon =  0.7995241415819182 , and episode is : 34
# Exploring
# Exploring
# Epsilon =  0.7994961587266657 , and episode is : 35
# Exploring
# Epsilon =  0.7994673773830188 , and episode is : 36
# Exploring
# Epsilon =  0.7994377976372842 , and episode is : 37
# Epsilon =  0.7994074195781607 , and episode is : 38
# Exploring
# Exploring
# Epsilon =  0.7993762432967386 , and episode is : 39
# Exploring
# Epsilon =  0.7993442688864992 , and episode is : 40
# Exploring
# Exploring
# Epsilon =  0.7993114964433146 , and episode is : 41
# Exploring
# Exploring
# Epsilon =  0.7992779260654468 , and episode is : 42
# Exploring
# Exploring
# Epsilon =  0.7992435578535477 , and episode is : 43
# Exploring
# Epsilon =  0.7992083919106585 , and episode is : 44
# Exploring
# Exploring
# Epsilon =  0.7991724283422089 , and episode is : 45
# Exploring
# Exploring
# Epsilon =  0.7991356672560167 , and episode is : 46
# Exploring
# Epsilon =  0.7990981087622872 , and episode is : 47
# Exploring
# Exploring
# Epsilon =  0.7990597529736129 , and episode is : 48
# Exploring
# Exploring
# Epsilon =  0.7990206000049728 , and episode is : 49
# Exploring
# Epsilon =  0.7989806499737316 , and episode is : 50
# Exploring
# Epsilon =  0.7989399029996397 , and episode is : 51
# Exploring
# Epsilon =  0.7988983592048318 , and episode is : 52
# Exploring
# Exploring
# Epsilon =  0.7988560187138268 , and episode is : 53
# Exploring
# Exploring
# Epsilon =  0.7988128816535274 , and episode is : 54
# Exploring
# Exploring
# Epsilon =  0.7987689481532187 , and episode is : 55
# Exploring
# Exploring
# Epsilon =  0.7987242183445685 , and episode is : 56
# Exploring
# Exploring
# Epsilon =  0.7986786923616257 , and episode is : 57
# Exploring
# Epsilon =  0.7986323703408202 , and episode is : 58
# Exploring
# Epsilon =  0.7985852524209625 , and episode is : 59
# Exploring
# Exploring
# Epsilon =  0.798537338743242 , and episode is : 60
# Exploring
# Exploring
# Epsilon =  0.7984886294512271 , and episode is : 61
# Exploring
# Exploring
# Epsilon =  0.7984391246908645 , and episode is : 62
# Epsilon =  0.7983888246104782 , and episode is : 63
# Exploring
# Exploring
# Epsilon =  0.7983377293607685 , and episode is : 64
# Exploring
# Epsilon =  0.798285839094812 , and episode is : 65
# Exploring
# Exploring
# Epsilon =  0.79823315396806 , and episode is : 66
# Exploring
# Epsilon =  0.7981796741383386 , and episode is : 67
# Exploring
# Exploring
# Epsilon =  0.7981253997658467 , and episode is : 68
# Exploring
# Exploring
# Epsilon =  0.7980703310131567 , and episode is : 69
# Exploring
# Exploring
# Epsilon =  0.7980144680452125 , and episode is : 70
# Exploring
# Exploring
# Epsilon =  0.7979578110293292 , and episode is : 71
# Exploring
# Epsilon =  0.797900360135192 , and episode is : 72
# Exploring
# Epsilon =  0.797842115534856 , and episode is : 73
# Exploring
# Epsilon =  0.7977830774027441 , and episode is : 74
# Exploring
# Exploring
# Epsilon =  0.7977232459156477 , and episode is : 75
# Exploring
# Exploring
# Epsilon =  0.7976626212527245 , and episode is : 76
# Exploring
# Exploring
# Epsilon =  0.7976012035954981 , and episode is : 77
# Exploring
# Exploring
# Epsilon =  0.7975389931278575 , and episode is : 78
# Exploring
# Exploring
# Epsilon =  0.7974759900360553 , and episode is : 79
# Exploring
# Exploring
# Epsilon =  0.7974121945087076 , and episode is : 80
# Exploring
# Epsilon =  0.7973476067367924 , and episode is : 81
# Exploring
# Exploring
# Epsilon =  0.7972822269136494 , and episode is : 82
# Epsilon =  0.7972160552349782 , and episode is : 83
# Exploring
# Exploring
# Epsilon =  0.797149091898838 , and episode is : 84
# Exploring
# Epsilon =  0.797081337105646 , and episode is : 85
# Exploring
# Exploring
# Epsilon =  0.7970127910581771 , and episode is : 86
# Exploring
# Exploring
# Epsilon =  0.7969434539615625 , and episode is : 87
# Exploring
# Epsilon =  0.7968733260232884 , and episode is : 88
# Exploring
# Exploring
# Epsilon =  0.7968024074531955 , and episode is : 89
# Exploring
# Epsilon =  0.7967306984634777 , and episode is : 90
# Exploring
# Exploring
# Epsilon =  0.7966581992686809 , and episode is : 91
# Exploring
# Exploring
# Epsilon =  0.7965849100857022 , and episode is : 92
# Exploring
# Exploring
# Epsilon =  0.796510831133789 , and episode is : 93
# Exploring
# Exploring
# Epsilon =  0.796435962634537 , and episode is : 94
# Exploring
# Exploring
# Epsilon =  0.7963603048118901 , and episode is : 95
# Exploring
# Exploring
# Epsilon =  0.7962838578921391 , and episode is : 96
# Exploring
# Epsilon =  0.7962066221039198 , and episode is : 97
# Exploring
# Exploring
# Epsilon =  0.7961285976782129 , and episode is : 98
# Exploring
# Exploring
# Epsilon =  0.7960497848483422 , and episode is : 99
# Exploring
# Epsilon =  0.7959701838499736 , and episode is : 100
# Exploring
# Exploring
# Epsilon =  0.795889794921114 , and episode is : 101
# Exploring
# Epsilon =  0.79580861830211 , and episode is : 102
# Exploring
# Exploring
# Epsilon =  0.7957266542356468 , and episode is : 103
# Exploring
# Exploring
# Epsilon =  0.7956439029667469 , and episode is : 104
# Exploring
# Exploring
# Epsilon =  0.7955603647427689 , and episode is : 105
# Epsilon =  0.7954760398134064 , and episode is : 106
# Exploring
# Exploring
# Epsilon =  0.7953909284306866 , and episode is : 107
# Exploring
# Exploring
# Epsilon =  0.795305030848969 , and episode is : 108
# Exploring
# Epsilon =  0.7952183473249443 , and episode is : 109
# Exploring
# Exploring
# Epsilon =  0.7951308781176332 , and episode is : 110
# Exploring
# Exploring
# Epsilon =  0.7950426234883847 , and episode is : 111
# Exploring
# Exploring
# Epsilon =  0.7949535837008752 , and episode is : 112
# Exploring
# Exploring
# Epsilon =  0.7948637590211071 , and episode is : 113
# Exploring
# Exploring
# Epsilon =  0.7947731497174071 , and episode is : 114
# Exploring
# Epsilon =  0.7946817560604256 , and episode is : 115
# Epsilon =  0.7945895783231346 , and episode is : 116
# Exploring
# Exploring
# Epsilon =  0.7944966167808271 , and episode is : 117
# Exploring
# Epsilon =  0.7944028717111148 , and episode is : 118
# Exploring
# Exploring
# Epsilon =  0.7943083433939275 , and episode is : 119
# Exploring
# Exploring
# Epsilon =  0.7942130321115116 , and episode is : 120
# Exploring
# Exploring
# Epsilon =  0.7941169381484281 , and episode is : 121
# Exploring
# Exploring
# Epsilon =  0.7940200617915519 , and episode is : 122
# Exploring
# Exploring
# Epsilon =  0.79392240333007 , and episode is : 123
# Exploring
# Exploring
# Epsilon =  0.7938239630554803 , and episode is : 124
# Exploring
# Exploring
# Epsilon =  0.7937247412615898 , and episode is : 125
# Exploring
# Exploring
# Epsilon =  0.7936247382445132 , and episode is : 126
# Exploring
# Epsilon =  0.7935239543026719 , and episode is : 127
# Exploring
# Exploring
# Epsilon =  0.793422389736792 , and episode is : 128
# Exploring
# Exploring
# Epsilon =  0.793320044849903 , and episode is : 129
# Exploring
# Exploring
# Epsilon =  0.7932169199473365 , and episode is : 130
# Exploring
# Exploring
# Epsilon =  0.7931130153367238 , and episode is : 131
# Exploring
# Exploring
# Epsilon =  0.793008331327996 , and episode is : 132
# Exploring
# Exploring
# Epsilon =  0.7929028682333806 , and episode is : 133
# Exploring
# Exploring
# Epsilon =  0.7927966263674013 , and episode is : 134
# Exploring
# Exploring
# Epsilon =  0.7926896060468759 , and episode is : 135
# Exploring
# Exploring
# Epsilon =  0.7925818075909147 , and episode is : 136
# Exploring
# Epsilon =  0.7924732313209191 , and episode is : 137
# Exploring
# Exploring
# Epsilon =  0.7923638775605798 , and episode is : 138
# Exploring
# Exploring
# Epsilon =  0.7922537466358754 , and episode is : 139
# Exploring
# Epsilon =  0.7921428388750709 , and episode is : 140
# Exploring
# Exploring
# Epsilon =  0.7920311546087153 , and episode is : 141
# Exploring
# Exploring
# Epsilon =  0.791918694169641 , and episode is : 142
# Exploring
# Exploring
# Epsilon =  0.7918054578929615 , and episode is : 143
# Exploring
# Exploring
# Epsilon =  0.7916914461160699 , and episode is : 144
# Epsilon =  0.7915766591786372 , and episode is : 145
# Exploring
# Exploring
# Epsilon =  0.7914610974226106 , and episode is : 146
# Exploring
# Exploring
# Epsilon =  0.7913447611922119 , and episode is : 147
# Exploring
# Exploring
# Epsilon =  0.7912276508339356 , and episode is : 148
# Exploring
# Exploring
# Epsilon =  0.7911097666965478 , and episode is : 149
# Exploring
# Exploring
# Epsilon =  0.7909911091310832 , and episode is : 150
# Exploring
# Exploring
# Epsilon =  0.7908716784908446 , and episode is : 151
# Exploring
# Epsilon =  0.7907514751314008 , and episode is : 152
# Exploring
# Exploring
# Epsilon =  0.7906304994105843 , and episode is : 153
# Exploring
# Epsilon =  0.7905087516884902 , and episode is : 154
# Exploring
# Epsilon =  0.7903862323274743 , and episode is : 155
# Exploring
# Exploring
# Epsilon =  0.7902629416921508 , and episode is : 156
# Exploring
# Exploring
# Epsilon =  0.7901388801493912 , and episode is : 157
# Exploring
# Epsilon =  0.7900140480683217 , and episode is : 158
# Exploring
# Exploring
# Epsilon =  0.7898884458203221 , and episode is : 159
# Exploring
# Epsilon =  0.7897620737790237 , and episode is : 160
# Exploring
# Epsilon =  0.7896349323203073 , and episode is : 161
# Exploring
# Exploring
# Epsilon =  0.7895070218223015 , and episode is : 162
# Exploring
# Exploring
# Epsilon =  0.7893783426653807 , and episode is : 163
# Exploring
# Epsilon =  0.7892488952321632 , and episode is : 164
# Exploring
# Exploring
# Epsilon =  0.7891186799075096 , and episode is : 165
# Exploring
# Exploring
# Epsilon =  0.7889876970785206 , and episode is : 166
# Exploring
# Exploring
# Epsilon =  0.788855947134535 , and episode is : 167
# Exploring
# Epsilon =  0.7887234304671282 , and episode is : 168
# Epsilon =  0.7885901474701098 , and episode is : 169
# Epsilon =  0.7884560985395218 , and episode is : 170
# Exploring
# Epsilon =  0.7883212840736369 , and episode is : 171
# Exploring
# Epsilon =  0.7881857044729561 , and episode is : 172
# Exploring
# Exploring
# Epsilon =  0.7880493601402072 , and episode is : 173
# Epsilon =  0.7879122514803422 , and episode is : 174
# Exploring
# Epsilon =  0.7877743789005357 , and episode is : 175
# Exploring
# Epsilon =  0.787635742810183 , and episode is : 176
# Exploring
# Epsilon =  0.7874963436208977 , and episode is : 177
# Exploring
# Exploring
# Epsilon =  0.7873561817465101 , and episode is : 178
# Exploring
# Epsilon =  0.7872152576030647 , and episode is : 179
# Exploring
# Epsilon =  0.7870735716088182 , and episode is : 180
# Exploring
# Epsilon =  0.7869311241842378 , and episode is : 181
# Exploring
# Epsilon =  0.786787915751999 , and episode is : 182
# Exploring
# Exploring
# Epsilon =  0.7866439467369831 , and episode is : 183
# Exploring
# Exploring
# Epsilon =  0.7864992175662755 , and episode is : 184
# Exploring
# Exploring
# Epsilon =  0.7863537286691638 , and episode is : 185
# Exploring
# Exploring
# Epsilon =  0.7862074804771347 , and episode is : 186
# Exploring
# Epsilon =  0.7860604734238734 , and episode is : 187
# Exploring
# Epsilon =  0.7859127079452599 , and episode is : 188
# Exploring
# Exploring
# Epsilon =  0.7857641844793679 , and episode is : 189
# Exploring
# Epsilon =  0.7856149034664622 , and episode is : 190
# Exploring
# Exploring
# Epsilon =  0.7854648653489965 , and episode is : 191
# Exploring
# Epsilon =  0.7853140705716114 , and episode is : 192
# Exploring
# Epsilon =  0.7851625195811321 , and episode is : 193
# Exploring
# Exploring
# Epsilon =  0.7850102128265664 , and episode is : 194
# Exploring
# Exploring
# Epsilon =  0.7848571507591018 , and episode is : 195
# Exploring
# Epsilon =  0.7847033338321042 , and episode is : 196
# Exploring
# Exploring
# Epsilon =  0.7845487625011153 , and episode is : 197
# Exploring
# Exploring
# Epsilon =  0.78439343722385 , and episode is : 198
# Exploring
# Exploring
# Epsilon =  0.7842373584601946 , and episode is : 199
# Exploring
# Exploring
# Epsilon =  0.7840805266722042 , and episode is : 200
# Exploring
# Epsilon =  0.7839229423241006 , and episode is : 201
# Exploring
# Epsilon =  0.7837646058822703 , and episode is : 202
# Exploring
# Epsilon =  0.7836055178152612 , and episode is : 203
# Exploring
# Epsilon =  0.7834456785937818 , and episode is : 204
# Exploring
# Exploring
# Epsilon =  0.7832850886906975 , and episode is : 205
# Exploring
# Epsilon =  0.7831237485810291 , and episode is : 206
# Exploring
# Epsilon =  0.7829616587419499 , and episode is : 207
# Exploring
# Exploring
# Epsilon =  0.782798819652784 , and episode is : 208
# Exploring
# Epsilon =  0.7826352317950032 , and episode is : 209
# Exploring
# Epsilon =  0.7824708956522252 , and episode is : 210
# Exploring
# Exploring
# Epsilon =  0.7823058117102109 , and episode is : 211
# Exploring
# Epsilon =  0.7821399804568623 , and episode is : 212
# Exploring
# Exploring
# Epsilon =  0.7819734023822197 , and episode is : 213
# Exploring
# Exploring
# Epsilon =  0.7818060779784596 , and episode is : 214
# Exploring
# Exploring
# Epsilon =  0.7816380077398923 , and episode is : 215
# Exploring
# Exploring
# Epsilon =  0.7814691921629592 , and episode is : 216
# Exploring
# Exploring
# Epsilon =  0.7812996317462304 , and episode is : 217
# Exploring
# Exploring
# Epsilon =  0.7811293269904026 , and episode is : 218
# Exploring
# Exploring
# Epsilon =  0.7809582783982962 , and episode is : 219
# Exploring
# Exploring
# Epsilon =  0.780786486474853 , and episode is : 220
# Exploring
# Epsilon =  0.780613951727134 , and episode is : 221
# Exploring
# Exploring
# Epsilon =  0.7804406746643162 , and episode is : 222
# Exploring
# Exploring
# Epsilon =  0.7802666557976908 , and episode is : 223
# Exploring
# Exploring
# Epsilon =  0.7800918956406604 , and episode is : 224
# Exploring
# Exploring
# Epsilon =  0.7799163947087365 , and episode is : 225
# Exploring
# Exploring
# Epsilon =  0.7797401535195368 , and episode is : 226
# Exploring
# Exploring
# Epsilon =  0.7795631725927831 , and episode is : 227
# Exploring
# Exploring
# Epsilon =  0.779385452450298 , and episode is : 228
# Exploring
# Exploring
# Epsilon =  0.7792069936160033 , and episode is : 229
# Epsilon =  0.7790277966159166 , and episode is : 230
# Exploring
# Exploring
# Epsilon =  0.778847861978149 , and episode is : 231
# Exploring
# Exploring
# Epsilon =  0.778667190232903 , and episode is : 232
# Exploring
# Exploring
# Epsilon =  0.7784857819124688 , and episode is : 233
# Exploring
# Exploring
# Epsilon =  0.7783036375512226 , and episode is : 234
# Exploring
# Exploring
# Epsilon =  0.7781207576856238 , and episode is : 235
# Exploring
# Exploring
# Epsilon =  0.7779371428542123 , and episode is : 236
# Exploring
# Exploring
# Epsilon =  0.7777527935976057 , and episode is : 237
# Exploring
# Exploring
# Epsilon =  0.7775677104584967 , and episode is : 238
# Exploring
# Epsilon =  0.7773818939816506 , and episode is : 239
# Exploring
# Epsilon =  0.7771953447139025 , and episode is : 240
# Exploring
# Exploring
# Epsilon =  0.7770080632041548 , and episode is : 241
# Exploring
# Epsilon =  0.7768200500033743 , and episode is : 242
# Exploring
# Epsilon =  0.7766313056645894 , and episode is : 243
# Exploring
# Exploring
# Epsilon =  0.7764418307428876 , and episode is : 244
# Exploring
# Exploring
# Epsilon =  0.7762516257954132 , and episode is : 245
# Exploring
# Exploring
# Epsilon =  0.7760606913813634 , and episode is : 246
# Exploring
# Exploring
# Epsilon =  0.7758690280619865 , and episode is : 247
# Exploring
# Epsilon =  0.7756766364005793 , and episode is : 248
# Exploring
# Exploring
# Epsilon =  0.7754835169624834 , and episode is : 249
# Exploring
# Exploring
# Epsilon =  0.7752896703150833 , and episode is : 250
# Exploring
# Exploring
# Epsilon =  0.7750950970278033 , and episode is : 251
# Exploring
# Epsilon =  0.7748997976721047 , and episode is : 252
# Exploring
# Exploring
# Epsilon =  0.774703772821483 , and episode is : 253
# Exploring
# Exploring
# Epsilon =  0.7745070230514649 , and episode is : 254
# Epsilon =  0.774309548939606 , and episode is : 255
# Exploring
# Exploring
# Epsilon =  0.7741113510654878 , and episode is : 256
# Exploring
# Exploring
# Epsilon =  0.7739124300107144 , and episode is : 257
# Exploring
# Exploring
# Epsilon =  0.7737127863589102 , and episode is : 258
# Exploring
# Exploring
# Epsilon =  0.7735124206957167 , and episode is : 259
# Exploring
# Exploring
# Epsilon =  0.7733113336087899 , and episode is : 260
# Exploring
# Exploring
# Epsilon =  0.7731095256877973 , and episode is : 261
# Exploring
# Epsilon =  0.772906997524415 , and episode is : 262
# Exploring
# Exploring
# Epsilon =  0.772703749712325 , and episode is : 263
# Exploring
# Exploring
# Epsilon =  0.7724997828472118 , and episode is : 264
# Exploring
# Exploring
# Epsilon =  0.7722950975267601 , and episode is : 265
# Exploring
# Exploring
# Epsilon =  0.7720896943506516 , and episode is : 266
# Exploring
# Epsilon =  0.7718835739205618 , and episode is : 267
# Exploring
# Exploring
# Epsilon =  0.7716767368401579 , and episode is : 268
# Epsilon =  0.7714691837150948 , and episode is : 269
# Exploring
# Exploring
# Epsilon =  0.7712609151530129 , and episode is : 270
# Exploring
# Exploring
# Epsilon =  0.7710519317635347 , and episode is : 271
# Exploring
# Exploring
# Epsilon =  0.7708422341582623 , and episode is : 272
# Exploring
# Epsilon =  0.7706318229507736 , and episode is : 273
# Exploring
# Exploring
# Epsilon =  0.7704206987566206 , and episode is : 274
# Exploring
# Exploring
# Epsilon =  0.770208862193325 , and episode is : 275
# Exploring
# Exploring
# Epsilon =  0.769996313880376 , and episode is : 276
# Exploring
# Exploring
# Epsilon =  0.7697830544392273 , and episode is : 277
# Exploring
# Exploring
# Epsilon =  0.7695690844932938 , and episode is : 278
# Exploring
# Epsilon =  0.7693544046679484 , and episode is : 279
# Exploring
# Epsilon =  0.7691390155905193 , and episode is : 280
# Exploring
# Epsilon =  0.7689229178902872 , and episode is : 281
# Exploring
# Epsilon =  0.7687061121984815 , and episode is : 282
# Exploring
# Epsilon =  0.7684885991482776 , and episode is : 283
# Exploring
# Exploring
# Epsilon =  0.7682703793747941 , and episode is : 284
# Exploring
# Epsilon =  0.7680514535150892 , and episode is : 285
# Exploring
# Exploring
# Epsilon =  0.7678318222081578 , and episode is : 286
# Exploring
# Exploring
# Epsilon =  0.7676114860949287 , and episode is : 287
# Exploring
# Exploring
# Epsilon =  0.767390445818261 , and episode is : 288
# Exploring
# Epsilon =  0.7671687020229413 , and episode is : 289
# Exploring
# Exploring
# Epsilon =  0.7669462553556804 , and episode is : 290
# Exploring
# Epsilon =  0.7667231064651101 , and episode is : 291
# Exploring
# Exploring
# Epsilon =  0.7664992560017805 , and episode is : 292
# Exploring
# Epsilon =  0.766274704618156 , and episode is : 293
# Exploring
# Exploring
# Epsilon =  0.7660494529686134 , and episode is : 294
# Exploring
# Exploring
# Epsilon =  0.7658235017094369 , and episode is : 295
# Exploring
# Epsilon =  0.765596851498817 , and episode is : 296
# Exploring
# Exploring
# Epsilon =  0.7653695029968456 , and episode is : 297
# Exploring
# Exploring
# Epsilon =  0.7651414568655137 , and episode is : 298
# Epsilon =  0.7649127137687081 , and episode is : 299
# Exploring
# Epsilon =  0.7646832743722077 , and episode is : 300
# Exploring
# Epsilon =  0.7644531393436811 , and episode is : 301
# Exploring
# Exploring
# Epsilon =  0.7642223093526823 , and episode is : 302
# Exploring
# Exploring
# Epsilon =  0.7639907850706485 , and episode is : 303
# Exploring
# Exploring
# Epsilon =  0.7637585671708963 , and episode is : 304
# Epsilon =  0.7635256563286182 , and episode is : 305
# Exploring
# Exploring
# Epsilon =  0.76329205322088 , and episode is : 306
# Exploring
# Epsilon =  0.763057758526617 , and episode is : 307
# Exploring
# Epsilon =  0.7628227729266308 , and episode is : 308
# Exploring
# Epsilon =  0.7625870971035864 , and episode is : 309
# Exploring
# Exploring
# Epsilon =  0.7623507317420083 , and episode is : 310
# Exploring
# Epsilon =  0.7621136775282774 , and episode is : 311
# Exploring
# Epsilon =  0.761875935150628 , and episode is : 312
# Exploring
# Exploring
# Epsilon =  0.7616375052991442 , and episode is : 313
# Exploring
# Exploring
# Epsilon =  0.7613983886657564 , and episode is : 314
# Exploring
# Epsilon =  0.7611585859442381 , and episode is : 315
# Exploring
# Epsilon =  0.7609180978302029 , and episode is : 316
# Exploring
# Exploring
# Epsilon =  0.7606769250211006 , and episode is : 317
# Exploring
# Epsilon =  0.760435068216214 , and episode is : 318
# Exploring
# Epsilon =  0.7601925281166557 , and episode is : 319
# Exploring
# Exploring
# Epsilon =  0.7599493054253644 , and episode is : 320
# Exploring
# Epsilon =  0.759705400847102 , and episode is : 321
# Exploring
# Epsilon =  0.7594608150884498 , and episode is : 322
# Exploring
# Exploring
# Epsilon =  0.7592155488578047 , and episode is : 323
# Exploring
# Epsilon =  0.7589696028653771 , and episode is : 324
# Exploring
# Epsilon =  0.758722977823186 , and episode is : 325
# Exploring
# Exploring
# Epsilon =  0.7584756744450565 , and episode is : 326
# Exploring
# Exploring
# Epsilon =  0.7582276934466159 , and episode is : 327
# Exploring
# Exploring
# Epsilon =  0.7579790355452906 , and episode is : 328
# Exploring
# Epsilon =  0.7577297014603022 , and episode is : 329
# Exploring
# Epsilon =  0.7574796919126645 , and episode is : 330
# Exploring
# Exploring
# Epsilon =  0.7572290076251798 , and episode is : 331
# Exploring
# Exploring
# Epsilon =  0.7569776493224353 , and episode is : 332
# Exploring
# Exploring
# Epsilon =  0.7567256177307999 , and episode is : 333
# Exploring
# Exploring
# Epsilon =  0.7564729135784205 , and episode is : 334
# Exploring
# Exploring
# Epsilon =  0.7562195375952185 , and episode is : 335
# Exploring
# Exploring
# Epsilon =  0.7559654905128864 , and episode is : 336
# Exploring
# Epsilon =  0.7557107730648842 , and episode is : 337
# Exploring
# Epsilon =  0.7554553859864359 , and episode is : 338
# Exploring
# Exploring
# Epsilon =  0.7551993300145259 , and episode is : 339
# Exploring
# Epsilon =  0.7549426058878956 , and episode is : 340
# Exploring
# Exploring
# Epsilon =  0.7546852143470397 , and episode is : 341
# Exploring
# Exploring
# Epsilon =  0.7544271561342027 , and episode is : 342
# Exploring
# Exploring
# Epsilon =  0.7541684319933755 , and episode is : 343
# Exploring
# Exploring
# Epsilon =  0.7539090426702912 , and episode is : 344
# Exploring
# Exploring
# Epsilon =  0.7536489889124227 , and episode is : 345
# Exploring
# Epsilon =  0.7533882714689778 , and episode is : 346
# Exploring
# Epsilon =  0.7531268910908964 , and episode is : 347
# Exploring
# Epsilon =  0.7528648485308467 , and episode is : 348
# Exploring
# Epsilon =  0.7526021445432217 , and episode is : 349
# Exploring
# Exploring
# Epsilon =  0.7523387798841354 , and episode is : 350
# Exploring
# Epsilon =  0.7520747553114193 , and episode is : 351
# Exploring
# Epsilon =  0.7518100715846187 , and episode is : 352
# Exploring
# Epsilon =  0.7515447294649887 , and episode is : 353
# Exploring
# Epsilon =  0.7512787297154916 , and episode is : 354
# Exploring
# Exploring
# Epsilon =  0.7510120731007921 , and episode is : 355
# Exploring
# Epsilon =  0.7507447603872544 , and episode is : 356
# Exploring
# Epsilon =  0.7504767923429381 , and episode is : 357
# Exploring
# Exploring
# Epsilon =  0.7502081697375946 , and episode is : 358
# Exploring
# Epsilon =  0.7499388933426638 , and episode is : 359
# Exploring
# Exploring
# Epsilon =  0.7496689639312697 , and episode is : 360
# Exploring
# Epsilon =  0.7493983822782174 , and episode is : 361
# Exploring
# Exploring
# Epsilon =  0.749127149159989 , and episode is : 362
# Exploring
# Exploring
# Epsilon =  0.74885526535474 , and episode is : 363
# Exploring
# Exploring
# Epsilon =  0.7485827316422956 , and episode is : 364
# Exploring
# Exploring
# Epsilon =  0.748309548804147 , and episode is : 365
# Exploring
# Exploring
# Epsilon =  0.7480357176234476 , and episode is : 366
# Exploring
# Epsilon =  0.747761238885009 , and episode is : 367
# Exploring
# Epsilon =  0.747486113375298 , and episode is : 368
# Exploring
# Exploring
# Epsilon =  0.7472103418824321 , and episode is : 369
# Exploring
# Epsilon =  0.746933925196176 , and episode is : 370
# Exploring
# Epsilon =  0.746656864107938 , and episode is : 371
# Exploring
# Epsilon =  0.7463791594107659 , and episode is : 372
# Epsilon =  0.7461008118993437 , and episode is : 373
# Exploring
# Exploring
# Epsilon =  0.7458218223699873 , and episode is : 374
# Exploring
# Exploring
# Epsilon =  0.745542191620641 , and episode is : 375
# Exploring
# Exploring
# Epsilon =  0.7452619204508735 , and episode is : 376
# Exploring
# Epsilon =  0.7449810096618743 , and episode is : 377
# Exploring
# Exploring
# Epsilon =  0.7446994600564499 , and episode is : 378
# Exploring
# Exploring
# Epsilon =  0.7444172724390199 , and episode is : 379
# Exploring
# Exploring
# Epsilon =  0.7441344476156129 , and episode is : 380
# Exploring
# Exploring
# Epsilon =  0.743850986393863 , and episode is : 381
# Exploring
# Exploring
# Epsilon =  0.7435668895830062 , and episode is : 382
# Exploring
# Epsilon =  0.7432821579938759 , and episode is : 383
# Exploring
# Epsilon =  0.7429967924388994 , and episode is : 384
# Exploring
# Exploring
# Epsilon =  0.7427107937320941 , and episode is : 385
# Exploring
# Exploring
# Epsilon =  0.7424241626890637 , and episode is : 386
# Exploring
# Epsilon =  0.7421369001269941 , and episode is : 387
# Exploring
# Exploring
# Epsilon =  0.7418490068646494 , and episode is : 388
# Exploring
# Exploring
# Epsilon =  0.7415604837223685 , and episode is : 389
# Exploring
# Exploring
# Epsilon =  0.7412713315220608 , and episode is : 390
# Exploring
# Epsilon =  0.7409815510872025 , and episode is : 391
# Exploring
# Epsilon =  0.7406911432428326 , and episode is : 392
# Exploring
# Epsilon =  0.740400108815549 , and episode is : 393
# Exploring
# Exploring
# Epsilon =  0.7401084486335046 , and episode is : 394
# Exploring
# Exploring
# Epsilon =  0.7398161635264033 , and episode is : 395
# Exploring
# Exploring
# Epsilon =  0.7395232543254964 , and episode is : 396
# Epsilon =  0.7392297218635782 , and episode is : 397
# Exploring
# Epsilon =  0.7389355669749822 , and episode is : 398
# Exploring
# Epsilon =  0.7386407904955775 , and episode is : 399
# Exploring
# Exploring
# Epsilon =  0.7383453932627645 , and episode is : 400
# Exploring
# Epsilon =  0.7380493761154708 , and episode is : 401
# Exploring
# Exploring
# Epsilon =  0.7377527398941477 , and episode is : 402
# Exploring
# Epsilon =  0.7374554854407658 , and episode is : 403
# Exploring
# Exploring
# Epsilon =  0.7371576135988112 , and episode is : 404
# Exploring
# Exploring
# Epsilon =  0.7368591252132817 , and episode is : 405
# Exploring
# Exploring
# Epsilon =  0.7365600211306824 , and episode is : 406
# Epsilon =  0.7362603021990222 , and episode is : 407
# Exploring
# Exploring
# Epsilon =  0.7359599692678092 , and episode is : 408
# Exploring
# Exploring
# Epsilon =  0.7356590231880472 , and episode is : 409
# Exploring
# Epsilon =  0.7353574648122315 , and episode is : 410
# Exploring
# Exploring
# Epsilon =  0.7350552949943449 , and episode is : 411
# Epsilon =  0.7347525145898535 , and episode is : 412
# Exploring
# Epsilon =  0.734449124455703 , and episode is : 413
# Exploring
# Epsilon =  0.7341451254503145 , and episode is : 414
# Exploring
# Exploring
# Epsilon =  0.7338405184335803 , and episode is : 415
# Exploring
# Exploring
# Epsilon =  0.7335353042668603 , and episode is : 416
# Exploring
# Epsilon =  0.7332294838129773 , and episode is : 417
# Exploring
# Epsilon =  0.7329230579362133 , and episode is : 418
# Exploring
# Epsilon =  0.7326160275023058 , and episode is : 419
# Exploring
# Exploring
# Epsilon =  0.7323083933784431 , and episode is : 420
# Epsilon =  0.7320001564332604 , and episode is : 421
# Exploring
# Exploring
# Epsilon =  0.731691317536836 , and episode is : 422
# Exploring
# Exploring
# Epsilon =  0.7313818775606868 , and episode is : 423
# Exploring
# Exploring
# Epsilon =  0.7310718373777647 , and episode is : 424
# Exploring
# Exploring
# Epsilon =  0.7307611978624519 , and episode is : 425
# Exploring
# Exploring
# Epsilon =  0.7304499598905574 , and episode is : 426
# Exploring
# Epsilon =  0.7301381243393124 , and episode is : 427
# Exploring
# Exploring
# Epsilon =  0.7298256920873664 , and episode is : 428
# Exploring
# Exploring
# Epsilon =  0.7295126640147833 , and episode is : 429
# Epsilon =  0.7291990410030369 , and episode is : 430
# Exploring
# Exploring
# Epsilon =  0.7288848239350069 , and episode is : 431
# Exploring
# Exploring
# Epsilon =  0.7285700136949748 , and episode is : 432
# Epsilon =  0.7282546111686197 , and episode is : 433
# Exploring
# Epsilon =  0.7279386172430142 , and episode is : 434
# Exploring
# Exploring
# Epsilon =  0.7276220328066206 , and episode is : 435
# Exploring
# Exploring
# Epsilon =  0.7273048587492859 , and episode is : 436
# Exploring
# Exploring
# Epsilon =  0.7269870959622383 , and episode is : 437
# Exploring
# Epsilon =  0.726668745338083 , and episode is : 438
# Exploring
# Epsilon =  0.7263498077707977 , and episode is : 439
# Exploring
# Exploring
# Epsilon =  0.7260302841557289 , and episode is : 440
# Exploring
# Epsilon =  0.725710175389587 , and episode is : 441
# Exploring
# Epsilon =  0.725389482370443 , and episode is : 442
# Exploring
# Exploring
# Epsilon =  0.7250682059977236 , and episode is : 443
# Exploring
# Epsilon =  0.7247463471722073 , and episode is : 444
# Exploring
# Epsilon =  0.7244239067960203 , and episode is : 445
# Exploring
# Exploring
# Epsilon =  0.724100885772632 , and episode is : 446
# Exploring
# Exploring
# Epsilon =  0.723777285006851 , and episode is : 447
# Exploring
# Exploring
# Epsilon =  0.7234531054048208 , and episode is : 448
# Exploring
# Exploring
# Epsilon =  0.7231283478740156 , and episode is : 449
# Exploring
# Exploring
# Epsilon =  0.7228030133232363 , and episode is : 450
# Exploring
# Exploring
# Epsilon =  0.7224771026626057 , and episode is : 451
# Exploring
# Epsilon =  0.7221506168035648 , and episode is : 452
# Exploring
# Epsilon =  0.7218235566588685 , and episode is : 453
# Exploring
# Exploring
# Epsilon =  0.7214959231425812 , and episode is : 454
# Exploring
# Exploring
# Epsilon =  0.7211677171700722 , and episode is : 455
# Exploring
# Exploring
# Epsilon =  0.7208389396580125 , and episode is : 456
# Exploring
# Exploring
# Epsilon =  0.7205095915243693 , and episode is : 457
# Exploring
# Epsilon =  0.7201796736884026 , and episode is : 458
# Exploring
# Exploring
# Epsilon =  0.7198491870706607 , and episode is : 459
# Exploring
# Exploring
# Epsilon =  0.7195181325929756 , and episode is : 460
# Exploring
# Epsilon =  0.7191865111784593 , and episode is : 461
# Epsilon =  0.7188543237514992 , and episode is : 462
# Exploring
# Epsilon =  0.7185215712377534 , and episode is : 463
# Exploring
# Exploring
# Epsilon =  0.7181882545641475 , and episode is : 464
# Exploring
# Exploring
# Epsilon =  0.7178543746588693 , and episode is : 465
# Exploring
# Epsilon =  0.7175199324513648 , and episode is : 466
# Exploring
# Epsilon =  0.7171849288723341 , and episode is : 467
# Exploring
# Exploring
# Epsilon =  0.7168493648537269 , and episode is : 468
# Exploring
# Exploring
# Epsilon =  0.7165132413287383 , and episode is : 469
# Exploring
# Exploring
# Epsilon =  0.7161765592318043 , and episode is : 470
# Exploring
# Exploring
# Epsilon =  0.7158393194985978 , and episode is : 471
# Exploring
# Exploring
# Epsilon =  0.7155015230660239 , and episode is : 472
# Exploring
# Epsilon =  0.7151631708722158 , and episode is : 473
# Exploring
# Exploring
# Epsilon =  0.7148242638565304 , and episode is : 474
# Epsilon =  0.7144848029595442 , and episode is : 475
# Exploring
# Epsilon =  0.7141447891230485 , and episode is : 476
# Epsilon =  0.7138042232900453 , and episode is : 477
# Exploring
# Epsilon =  0.7134631064047433 , and episode is : 478
# Exploring
# Exploring
# Epsilon =  0.7131214394125528 , and episode is : 479
# Exploring
# Exploring
# Epsilon =  0.7127792232600819 , and episode is : 480
# Exploring
# Exploring
# Epsilon =  0.7124364588951322 , and episode is : 481
# Exploring
# Epsilon =  0.7120931472666938 , and episode is : 482
# Exploring
# Exploring
# Epsilon =  0.7117492893249417 , and episode is : 483
# Exploring
# Exploring
# Epsilon =  0.7114048860212312 , and episode is : 484
# Exploring
# Epsilon =  0.7110599383080931 , and episode is : 485
# Exploring
# Epsilon =  0.7107144471392297 , and episode is : 486
# Exploring
# Exploring
# Epsilon =  0.7103684134695105 , and episode is : 487
# Exploring
# Exploring
# Epsilon =  0.7100218382549676 , and episode is : 488
# Exploring
# Exploring
# Epsilon =  0.7096747224527914 , and episode is : 489
# Exploring
# Exploring
# Epsilon =  0.7093270670213262 , and episode is : 490
# Exploring
# Exploring
# Epsilon =  0.7089788729200659 , and episode is : 491
# Exploring
# Exploring
# Epsilon =  0.7086301411096492 , and episode is : 492
# Exploring
# Exploring
# Epsilon =  0.7082808725518557 , and episode is : 493
# Exploring
# Exploring
# Epsilon =  0.7079310682096014 , and episode is : 494
# Exploring
# Exploring
# Epsilon =  0.7075807290469339 , and episode is : 495
# Exploring
# Exploring
# Epsilon =  0.7072298560290284 , and episode is : 496
# Exploring
# Exploring
# Epsilon =  0.7068784501221832 , and episode is : 497
# Exploring
# Exploring
# Epsilon =  0.7065265122938151 , and episode is : 498
# Exploring
# Exploring
# Epsilon =  0.7061740435124553 , and episode is : 499
# Exploring
# Exploring
# Epsilon =  0.7058210447477444 , and episode is : 500
# Exploring
# Exploring
# Epsilon =  0.7054675169704286 , and episode is : 501
# Exploring
# Exploring
# Epsilon =  0.7051134611523552 , and episode is : 502
# Exploring
# Exploring
# Epsilon =  0.7047588782664673 , and episode is : 503
# Exploring
# Exploring
# Epsilon =  0.7044037692868008 , and episode is : 504
# Exploring
# Epsilon =  0.7040481351884788 , and episode is : 505
# Exploring
# Epsilon =  0.7036919769477074 , and episode is : 506
# Exploring
# Exploring
# Epsilon =  0.7033352955417717 , and episode is : 507
# Exploring
# Exploring
# Epsilon =  0.7029780919490308 , and episode is : 508
# Exploring
# Epsilon =  0.7026203671489137 , and episode is : 509
# Exploring
# Exploring
# Epsilon =  0.7022621221219146 , and episode is : 510
# Exploring
# Epsilon =  0.7019033578495887 , and episode is : 511
# Exploring
# Exploring
# Epsilon =  0.7015440753145473 , and episode is : 512
# Exploring
# Exploring
# Epsilon =  0.701184275500454 , and episode is : 513
# Exploring
# Epsilon =  0.7008239593920195 , and episode is : 514
# Exploring
# Exploring
# Epsilon =  0.7004631279749977 , and episode is : 515
# Epsilon =  0.7001017822361807 , and episode is : 516
# Exploring
# Epsilon =  0.699739923163395 , and episode is : 517
# Exploring
# Exploring
# Epsilon =  0.6993775517454963 , and episode is : 518
# Exploring
# Exploring
# Epsilon =  0.6990146689723656 , and episode is : 519
# Exploring
# Exploring
# Epsilon =  0.6986512758349043 , and episode is : 520
# Exploring
# Exploring
# Epsilon =  0.6982873733250295 , and episode is : 521
# Exploring
# Epsilon =  0.6979229624356706 , and episode is : 522
# Exploring
# Exploring
# Epsilon =  0.6975580441607636 , and episode is : 523
# Exploring
# Exploring
# Epsilon =  0.6971926194952471 , and episode is : 524
# Epsilon =  0.6968266894350579 , and episode is : 525
# Exploring
# Epsilon =  0.696460254977126 , and episode is : 526
# Exploring
# Exploring
# Epsilon =  0.6960933171193711 , and episode is : 527
# Exploring
# Exploring
# Epsilon =  0.6957258768606966 , and episode is : 528
# Exploring
# Epsilon =  0.6953579352009868 , and episode is : 529
# Exploring
# Exploring
# Epsilon =  0.6949894931411007 , and episode is : 530
# Epsilon =  0.6946205516828688 , and episode is : 531
# Exploring
# Exploring
# Epsilon =  0.694251111829088 , and episode is : 532
# Exploring
# Exploring
# Epsilon =  0.6938811745835171 , and episode is : 533
# Epsilon =  0.6935107409508721 , and episode is : 534
# Exploring
# Exploring
# Epsilon =  0.6931398119368221 , and episode is : 535
# Exploring
# Epsilon =  0.6927683885479845 , and episode is : 536
# Exploring
# Exploring
# Epsilon =  0.6923964717919207 , and episode is : 537
# Exploring
# Epsilon =  0.6920240626771311 , and episode is : 538
# Exploring
# Epsilon =  0.6916511622130512 , and episode is : 539
# Exploring
# Epsilon =  0.6912777714100464 , and episode is : 540
# Exploring
# Epsilon =  0.6909038912794079 , and episode is : 541
# Exploring
# Exploring
# Epsilon =  0.690529522833348 , and episode is : 542
# Exploring
# Exploring
# Epsilon =  0.6901546670849956 , and episode is : 543
# Exploring
# Epsilon =  0.6897793250483918 , and episode is : 544
# Exploring
# Epsilon =  0.6894034977384849 , and episode is : 545
# Exploring
# Exploring
# Epsilon =  0.6890271861711262 , and episode is : 546
# Exploring
# Epsilon =  0.6886503913630657 , and episode is : 547
# Exploring
# Epsilon =  0.6882731143319468 , and episode is : 548
# Epsilon =  0.6878953560963023 , and episode is : 549
# Exploring
# Exploring
# Epsilon =  0.6875171176755498 , and episode is : 550
# Exploring
# Epsilon =  0.687138400089987 , and episode is : 551
# Exploring
# Epsilon =  0.6867592043607871 , and episode is : 552
# Exploring
# Exploring
# Epsilon =  0.6863795315099944 , and episode is : 553
# Exploring
# Epsilon =  0.6859993825605197 , and episode is : 554
# Exploring
# Epsilon =  0.6856187585361356 , and episode is : 555
# Exploring
# Epsilon =  0.6852376604614719 , and episode is : 556
# Exploring
# Exploring
# Epsilon =  0.6848560893620113 , and episode is : 557
# Epsilon =  0.6844740462640845 , and episode is : 558
# Exploring
# Exploring
# Epsilon =  0.684091532194866 , and episode is : 559
# Epsilon =  0.6837085481823689 , and episode is : 560
# Exploring
# Exploring
# Epsilon =  0.6833250952554413 , and episode is : 561
# Exploring
# Exploring
# Epsilon =  0.6829411744437607 , and episode is : 562
# Epsilon =  0.68255678677783 , and episode is : 563
# Exploring
# Epsilon =  0.682171933288973 , and episode is : 564
# Exploring
# Epsilon =  0.6817866150093289 , and episode is : 565
# Exploring
# Epsilon =  0.6814008329718493 , and episode is : 566
# Exploring
# Exploring
# Epsilon =  0.6810145882102919 , and episode is : 567
# Exploring
# Epsilon =  0.6806278817592173 , and episode is : 568
# Exploring
# Exploring
# Epsilon =  0.6802407146539836 , and episode is : 569
# Exploring
# Exploring
# Epsilon =  0.679853087930742 , and episode is : 570
# Exploring
# Exploring
# Epsilon =  0.6794650026264322 , and episode is : 571
# Exploring
# Exploring
# Epsilon =  0.679076459778778 , and episode is : 572
# Exploring
# Exploring
# Epsilon =  0.6786874604262825 , and episode is : 573
# Epsilon =  0.6782980056082235 , and episode is : 574
# Exploring
# Exploring
# Epsilon =  0.6779080963646491 , and episode is : 575
# Epsilon =  0.6775177337363728 , and episode is : 576
# Epsilon =  0.677126918764969 , and episode is : 577
# Exploring
# Epsilon =  0.6767356524927685 , and episode is : 578
# Epsilon =  0.6763439359628538 , and episode is : 579
# Exploring
# Exploring
# Epsilon =  0.6759517702190547 , and episode is : 580
# Exploring
# Epsilon =  0.6755591563059434 , and episode is : 581
# Epsilon =  0.6751660952688301 , and episode is : 582
# Exploring
# Epsilon =  0.6747725881537581 , and episode is : 583
# Exploring
# Epsilon =  0.6743786360074996 , and episode is : 584
# Exploring
# Exploring
# Epsilon =  0.6739842398775509 , and episode is : 585
# Exploring
# Epsilon =  0.6735894008121276 , and episode is : 586
# Exploring
# Exploring
# Epsilon =  0.6731941198601604 , and episode is : 587
# Exploring
# Exploring
# Epsilon =  0.6727983980712902 , and episode is : 588
# Exploring
# Exploring
# Epsilon =  0.6724022364958632 , and episode is : 589
# Exploring
# Epsilon =  0.672005636184927 , and episode is : 590
# Exploring
# Epsilon =  0.6716085981902257 , and episode is : 591
# Exploring
# Exploring
# Epsilon =  0.6712111235641948 , and episode is : 592
# Exploring
# Exploring
# Epsilon =  0.6708132133599571 , and episode is : 593
# Epsilon =  0.6704148686313183 , and episode is : 594
# Exploring
# Exploring
# Epsilon =  0.6700160904327614 , and episode is : 595
# Exploring
# Exploring
# Epsilon =  0.6696168798194435 , and episode is : 596
# Exploring
# Epsilon =  0.6692172378471897 , and episode is : 597
# Exploring
# Exploring
# Epsilon =  0.6688171655724895 , and episode is : 598
# Exploring
# Epsilon =  0.6684166640524919 , and episode is : 599
# Exploring
# Exploring
# Epsilon =  0.6680157343450006 , and episode is : 600
# Exploring
# Epsilon =  0.6676143775084695 , and episode is : 601
# Exploring
# Exploring
# Epsilon =  0.6672125946019982 , and episode is : 602
# Exploring
# Exploring
# Epsilon =  0.6668103866853273 , and episode is : 603
# Exploring
# Epsilon =  0.6664077548188336 , and episode is : 604
# Exploring
# Exploring
# Epsilon =  0.6660047000635257 , and episode is : 605
# Exploring
# Epsilon =  0.6656012234810393 , and episode is : 606
# Exploring
# Exploring
# Epsilon =  0.6651973261336326 , and episode is : 607
# Exploring
# Exploring
# Epsilon =  0.6647930090841815 , and episode is : 608
# Exploring
# Epsilon =  0.6643882733961752 , and episode is : 609
# Exploring
# Exploring
# Epsilon =  0.6639831201337117 , and episode is : 610
# Exploring
# Epsilon =  0.6635775503614928 , and episode is : 611
# Exploring
# Exploring
# Epsilon =  0.6631715651448195 , and episode is : 612
# Exploring
# Exploring
# Epsilon =  0.6627651655495876 , and episode is : 613
# Exploring
# Epsilon =  0.6623583526422833 , and episode is : 614
# Exploring
# Epsilon =  0.6619511274899778 , and episode is : 615
# Exploring
# Epsilon =  0.6615434911603235 , and episode is : 616
# Exploring
# Epsilon =  0.6611354447215488 , and episode is : 617
# Exploring
# Epsilon =  0.6607269892424539 , and episode is : 618
# Exploring
# Epsilon =  0.6603181257924057 , and episode is : 619
# Exploring
# Exploring
# Epsilon =  0.6599088554413335 , and episode is : 620
# Exploring
# Epsilon =  0.6594991792597245 , and episode is : 621
# Exploring
# Exploring
# Epsilon =  0.6590890983186187 , and episode is : 622
# Exploring
# Epsilon =  0.6586786136896049 , and episode is : 623
# Exploring
# Exploring
# Epsilon =  0.6582677264448155 , and episode is : 624
# Exploring
# Epsilon =  0.657856437656922 , and episode is : 625
# Exploring
# Epsilon =  0.6574447483991307 , and episode is : 626
# Exploring
# Epsilon =  0.6570326597451778 , and episode is : 627
# Exploring
# Exploring
# Epsilon =  0.6566201727693247 , and episode is : 628
# Exploring
# Exploring
# Epsilon =  0.6562072885463538 , and episode is : 629
# Exploring
# Epsilon =  0.6557940081515632 , and episode is : 630
# Exploring
# Epsilon =  0.6553803326607627 , and episode is : 631
# Exploring
# Epsilon =  0.6549662631502688 , and episode is : 632
# Exploring
# Exploring
# Epsilon =  0.6545518006969004 , and episode is : 633
# Exploring
# Epsilon =  0.6541369463779738 , and episode is : 634
# Exploring
# Epsilon =  0.6537217012712983 , and episode is : 635
# Exploring
# Epsilon =  0.6533060664551714 , and episode is : 636
# Exploring
# Epsilon =  0.6528900430083747 , and episode is : 637
# Exploring
# Exploring
# Epsilon =  0.6524736320101686 , and episode is : 638
# Exploring
# Epsilon =  0.6520568345402881 , and episode is : 639
# Exploring
# Epsilon =  0.6516396516789378 , and episode is : 640
# Exploring
# Exploring
# Epsilon =  0.6512220845067878 , and episode is : 641
# Exploring
# Exploring
# Epsilon =  0.6508041341049687 , and episode is : 642
# Exploring
# Exploring
# Epsilon =  0.6503858015550673 , and episode is : 643
# Exploring
# Epsilon =  0.6499670879391215 , and episode is : 644
# Exploring
# Epsilon =  0.6495479943396161 , and episode is : 645
# Exploring
# Epsilon =  0.6491285218394779 , and episode is : 646
# Exploring
# Epsilon =  0.6487086715220716 , and episode is : 647
# Exploring
# Exploring
# Epsilon =  0.6482884444711944 , and episode is : 648
# Exploring
# Epsilon =  0.6478678417710719 , and episode is : 649
# Exploring
# Exploring
# Epsilon =  0.6474468645063537 , and episode is : 650
# Exploring
# Exploring
# Epsilon =  0.647025513762108 , and episode is : 651
# Exploring
# Exploring
# Epsilon =  0.6466037906238179 , and episode is : 652
# Exploring
# Epsilon =  0.6461816961773761 , and episode is : 653
# Exploring
# Epsilon =  0.6457592315090805 , and episode is : 654
# Epsilon =  0.6453363977056299 , and episode is : 655
# Exploring
# Exploring
# Epsilon =  0.6449131958541189 , and episode is : 656
# Exploring
# Epsilon =  0.6444896270420336 , and episode is : 657
# Exploring
# Exploring
# Epsilon =  0.644065692357247 , and episode is : 658
# Exploring
# Epsilon =  0.6436413928880141 , and episode is : 659
# Exploring
# Epsilon =  0.6432167297229678 , and episode is : 660
# Exploring
# Exploring
# Epsilon =  0.6427917039511137 , and episode is : 661
# Exploring
# Exploring
# Epsilon =  0.6423663166618261 , and episode is : 662
# Exploring
# Epsilon =  0.641940568944843 , and episode is : 663
# Epsilon =  0.6415144618902615 , and episode is : 664
# Exploring
# Epsilon =  0.6410879965885334 , and episode is : 665
# Exploring
# Epsilon =  0.6406611741304606 , and episode is : 666
# Exploring
# Exploring
# Epsilon =  0.6402339956071904 , and episode is : 667
# Exploring
# Exploring
# Epsilon =  0.6398064621102107 , and episode is : 668
# Exploring
# Exploring
# Epsilon =  0.6393785747313461 , and episode is : 669
# Exploring
# Exploring
# Epsilon =  0.6389503345627523 , and episode is : 670
# Exploring
# Exploring
# Epsilon =  0.6385217426969125 , and episode is : 671
# Exploring
# Exploring
# Epsilon =  0.6380928002266322 , and episode is : 672
# Exploring
# Exploring
# Epsilon =  0.6376635082450347 , and episode is : 673
# Epsilon =  0.6372338678455568 , and episode is : 674
# Epsilon =  0.6368038801219439 , and episode is : 675
# Exploring
# Exploring
# Epsilon =  0.6363735461682455 , and episode is : 676
# Epsilon =  0.6359428670788108 , and episode is : 677
# Exploring
# Epsilon =  0.6355118439482838 , and episode is : 678
# Exploring
# Epsilon =  0.635080477871599 , and episode is : 679
# Exploring
# Exploring
# Epsilon =  0.6346487699439769 , and episode is : 680
# Exploring
# Epsilon =  0.6342167212609189 , and episode is : 681
# Exploring
# Exploring
# Epsilon =  0.6337843329182032 , and episode is : 682
# Exploring
# Exploring
# Epsilon =  0.6333516060118805 , and episode is : 683
# Exploring
# Epsilon =  0.6329185416382684 , and episode is : 684
# Exploring
# Epsilon =  0.632485140893948 , and episode is : 685
# Exploring
# Exploring
# Epsilon =  0.6320514048757585 , and episode is : 686
# Exploring
# Exploring
# Epsilon =  0.6316173346807932 , and episode is : 687
# Exploring
# Epsilon =  0.6311829314063944 , and episode is : 688
# Exploring
# Epsilon =  0.6307481961501493 , and episode is : 689
# Exploring
# Epsilon =  0.6303131300098854 , and episode is : 690
# Exploring
# Exploring
# Epsilon =  0.6298777340836655 , and episode is : 691
# Exploring
# Epsilon =  0.6294420094697838 , and episode is : 692
# Exploring
# Epsilon =  0.6290059572667607 , and episode is : 693
# Exploring
# Epsilon =  0.6285695785733388 , and episode is : 694
# Epsilon =  0.6281328744884781 , and episode is : 695
# Epsilon =  0.6276958461113513 , and episode is : 696
# Exploring
# Epsilon =  0.6272584945413396 , and episode is : 697
# Exploring
# Epsilon =  0.6268208208780279 , and episode is : 698
# Exploring
# Epsilon =  0.6263828262212005 , and episode is : 699
# Exploring
# Exploring
# Epsilon =  0.6259445116708361 , and episode is : 700
# Exploring
# Exploring
# Epsilon =  0.6255058783271039 , and episode is : 701
# Epsilon =  0.6250669272903586 , and episode is : 702
# Exploring
# Exploring
# Epsilon =  0.624627659661136 , and episode is : 703
# Exploring
# Exploring
# Epsilon =  0.6241880765401485 , and episode is : 704
# Exploring
# Exploring
# Epsilon =  0.6237481790282807 , and episode is : 705
# Exploring
# Exploring
# Epsilon =  0.6233079682265845 , and episode is : 706
# Exploring
# Exploring
# Epsilon =  0.622867445236275 , and episode is : 707
# Epsilon =  0.6224266111587257 , and episode is : 708
# Exploring
# Exploring
# ...
# Exploring
# Epsilon =  0.6031921047512978 , and episode is : 751
# Epsilon =  0.6027386747995548 , and episode is : 752
# Exploring
# Epsilon =  0.6022849834136748 , and episode is : 753
# Exploring
# Epsilon =  0.6018310316974844 , and episode is : 754
# Exploring
# Exploring
# Epsilon =  0.6013768207547596 , and episode is : 755
# Exploring
# Epsilon =  0.6009223516892213 , and episode is : 756
# Epsilon =  0.6004676256045306 , and episode is : 757
# Exploring
# Epsilon =  0.6000126436042852 , and episode is : 758
# Epsilon =  0.5995574067920142 , and episode is : 759
# Exploring
# Epsilon =  0.5991019162711745 , and episode is : 760
# Epsilon =  0.5986461731451458 , and episode is : 761
# Epsilon =  0.5981901785172267 , and episode is : 762
# Epsilon =  0.59773393349063 , and episode is : 763
# Exploring
# Exploring
# Epsilon =  0.5972774391684786 , and episode is : 764
# Exploring
# Epsilon =  0.5968206966538014 , and episode is : 765
# Exploring
# Exploring
# Epsilon =  0.5963637070495282 , and episode is : 766
# Exploring
# Epsilon =  0.595906471458486 , and episode is : 767
# Exploring
# Exploring
# Epsilon =  0.5954489909833943 , and episode is : 768
# Exploring
# Exploring
# Epsilon =  0.5949912667268614 , and episode is : 769
# Exploring
# Exploring
# Epsilon =  0.5945332997913793 , and episode is : 770
# Epsilon =  0.5940750912793197 , and episode is : 771
# Exploring
# Exploring
# Epsilon =  0.5936166422929298 , and episode is : 772
# Exploring
# Exploring
# Epsilon =  0.5931579539343279 , and episode is : 773
# Exploring
# Exploring
# Epsilon =  0.5926990273054991 , and episode is : 774
# Exploring
# Epsilon =  0.5922398635082908 , and episode is : 775
# Exploring
# Epsilon =  0.591780463644409 , and episode is : 776
# Exploring
# Epsilon =  0.5913208288154128 , and episode is : 777
# Exploring
# Exploring
# Epsilon =  0.5908609601227118 , and episode is : 778
# Exploring
# Exploring
# Epsilon =  0.5904008586675604 , and episode is : 779
# Exploring
# Exploring
# Epsilon =  0.589940525551054 , and episode is : 780
# Exploring
# Exploring
# Epsilon =  0.589479961874125 , and episode is : 781
# Exploring
# Exploring
# Epsilon =  0.589019168737538 , and episode is : 782
# Exploring
# Epsilon =  0.588558147241886 , and episode is : 783
# Exploring
# Epsilon =  0.5880968984875858 , and episode is : 784
# Exploring
# Epsilon =  0.5876354235748741 , and episode is : 785
# Exploring
# Epsilon =  0.5871737236038026 , and episode is : 786
# Exploring
# Exploring
# Epsilon =  0.5867117996742345 , and episode is : 787
# Exploring
# Epsilon =  0.5862496528858397 , and episode is : 788
# Exploring
# Epsilon =  0.585787284338091 , and episode is : 789
# Exploring
# Epsilon =  0.5853246951302595 , and episode is : 790
# Exploring
# Epsilon =  0.5848618863614105 , and episode is : 791
# Epsilon =  0.5843988591303991 , and episode is : 792
# Exploring
# Exploring
# Epsilon =  0.5839356145358664 , and episode is : 793
# Exploring
# Exploring
# Epsilon =  0.5834721536762347 , and episode is : 794
# Exploring
# Exploring
# Epsilon =  0.583008477649704 , and episode is : 795
# Exploring
# Exploring
# Epsilon =  0.5825445875542469 , and episode is : 796
# Exploring
# Exploring
# Epsilon =  0.5820804844876051 , and episode is : 797
# Exploring
# Epsilon =  0.581616169547285 , and episode is : 798
# Exploring
# Epsilon =  0.5811516438305534 , and episode is : 799
# Exploring
# Exploring
# Epsilon =  0.5806869084344333 , and episode is : 800
# Exploring
# Epsilon =  0.5802219644556998 , and episode is : 801
# Exploring
# Exploring
# Epsilon =  0.579756812990876 , and episode is : 802
# Exploring
# Exploring
# Epsilon =  0.5792914551362285 , and episode is : 803
# Exploring
# Exploring
# Epsilon =  0.5788258919877636 , and episode is : 804
# Epsilon =  0.5783601246412228 , and episode is : 805
# Exploring
# Exploring
# Epsilon =  0.5778941541920789 , and episode is : 806
# Exploring
# Epsilon =  0.5774279817355317 , and episode is : 807
# Exploring
# Epsilon =  0.5769616083665037 , and episode is : 808
# Exploring
# Epsilon =  0.5764950351796362 , and episode is : 809
# Exploring
# Exploring
# Epsilon =  0.5760282632692851 , and episode is : 810
# Exploring
# Exploring
# Epsilon =  0.5755612937295167 , and episode is : 811
# Epsilon =  0.5750941276541035 , and episode is : 812
# Exploring
# Epsilon =  0.5746267661365202 , and episode is : 813
# Exploring
# Epsilon =  0.5741592102699394 , and episode is : 814
# Epsilon =  0.5736914611472279 , and episode is : 815
# Exploring
# Epsilon =  0.5732235198609418 , and episode is : 816
# Exploring
# Epsilon =  0.5727553875033229 , and episode is : 817
# Epsilon =  0.5722870651662948 , and episode is : 818
# Exploring
# Epsilon =  0.5718185539414584 , and episode is : 819
# Exploring
# Epsilon =  0.5713498549200879 , and episode is : 820
# Exploring
# Epsilon =  0.5708809691931268 , and episode is : 821
# Exploring
# Epsilon =  0.5704118978511836 , and episode is : 822
# Exploring
# Exploring
# Epsilon =  0.5699426419845279 , and episode is : 823
# Epsilon =  0.5694732026830863 , and episode is : 824
# Exploring
# Epsilon =  0.5690035810364384 , and episode is : 825
# Exploring
# Epsilon =  0.5685337781338125 , and episode is : 826
# Exploring
# Epsilon =  0.5680637950640814 , and episode is : 827
# Exploring
# Exploring
# Epsilon =  0.567593632915759 , and episode is : 828
# Exploring
# Exploring
# Epsilon =  0.5671232927769958 , and episode is : 829
# Epsilon =  0.5666527757355747 , and episode is : 830
# Exploring
# Exploring
# Epsilon =  0.5661820828789073 , and episode is : 831
# Exploring
# Epsilon =  0.5657112152940295 , and episode is : 832
# Exploring
# Exploring
# Epsilon =  0.5652401740675979 , and episode is : 833
# Exploring
# Epsilon =  0.5647689602858854 , and episode is : 834
# Exploring
# Exploring
# Epsilon =  0.5642975750347775 , and episode is : 835
# Exploring
# Exploring
# Epsilon =  0.5638260193997678 , and episode is : 836
# Exploring
# Epsilon =  0.5633542944659546 , and episode is : 837
# Exploring
# Exploring
# Epsilon =  0.5628824013180365 , and episode is : 838
# Exploring
# Exploring
# Epsilon =  0.5624103410403082 , and episode is : 839
# Epsilon =  0.5619381147166571 , and episode is : 840
# Exploring
# Exploring
# Epsilon =  0.561465723430559 , and episode is : 841
# Epsilon =  0.5609931682650738 , and episode is : 842
# Exploring
# Epsilon =  0.5605204503028421 , and episode is : 843
# Exploring
# Exploring
# Epsilon =  0.5600475706260809 , and episode is : 844
# Exploring
# Epsilon =  0.5595745303165794 , and episode is : 845
# Exploring
# Exploring
# Epsilon =  0.5591013304556959 , and episode is : 846
# Exploring
# Exploring
# Epsilon =  0.5586279721243524 , and episode is : 847
# Exploring
# Epsilon =  0.5581544564030324 , and episode is : 848
# Exploring
# Epsilon =  0.5576807843717755 , and episode is : 849
# Exploring
# Exploring
# Epsilon =  0.557206957110174 , and episode is : 850
# Exploring
# Epsilon =  0.5567329756973692 , and episode is : 851
# Exploring
# Epsilon =  0.5562588412120472 , and episode is : 852
# Exploring
# Exploring
# Epsilon =  0.5557845547324347 , and episode is : 853
# Exploring
# Epsilon =  0.5553101173362959 , and episode is : 854
# Exploring
# Epsilon =  0.5548355301009277 , and episode is : 855
# Exploring
# Epsilon =  0.5543607941031563 , and episode is : 856
# Exploring
# Epsilon =  0.5538859104193332 , and episode is : 857
# Exploring
# Exploring
# Epsilon =  0.5534108801253312 , and episode is : 858
# Epsilon =  0.5529357042965406 , and episode is : 859
# Epsilon =  0.5524603840078652 , and episode is : 860
# Epsilon =  0.5519849203337188 , and episode is : 861
# Exploring
# Exploring
# Epsilon =  0.5515093143480208 , and episode is : 862
# Exploring
# Epsilon =  0.5510335671241923 , and episode is : 863
# Exploring
# Exploring
# Epsilon =  0.550557679735153 , and episode is : 864
# Epsilon =  0.5500816532533167 , and episode is : 865
# Exploring
# Epsilon =  0.5496054887505876 , and episode is : 866
# Epsilon =  0.5491291872983562 , and episode is : 867
# Exploring
# Exploring
# Epsilon =  0.5486527499674961 , and episode is : 868
# Epsilon =  0.5481761778283596 , and episode is : 869
# Exploring
# Epsilon =  0.547699471950774 , and episode is : 870
# Exploring
# Epsilon =  0.5472226334040377 , and episode is : 871
# Exploring
# Epsilon =  0.5467456632569169 , and episode is : 872
# Epsilon =  0.5462685625776411 , and episode is : 873
# Exploring
# Exploring
# Epsilon =  0.5457913324338998 , and episode is : 874
# Exploring
# Epsilon =  0.5453139738928383 , and episode is : 875
# Epsilon =  0.5448364880210543 , and episode is : 876
# Epsilon =  0.5443588758845938 , and episode is : 877
# Exploring
# Epsilon =  0.5438811385489474 , and episode is : 878
# Exploring
# Epsilon =  0.5434032770790468 , and episode is : 879
# Epsilon =  0.5429252925392607 , and episode is : 880
# Epsilon =  0.542447185993391 , and episode is : 881
# Exploring
# Exploring
# Epsilon =  0.5419689585046694 , and episode is : 882
# Epsilon =  0.5414906111357534 , and episode is : 883
# Exploring
# Exploring
# Epsilon =  0.5410121449487224 , and episode is : 884
# Exploring
# Exploring
# Epsilon =  0.5405335610050744 , and episode is : 885
# Exploring
# Epsilon =  0.540054860365722 , and episode is : 886
# Exploring
# Epsilon =  0.5395760440909887 , and episode is : 887
# Exploring
# Exploring
# Epsilon =  0.5390971132406049 , and episode is : 888
# Exploring
# Exploring
# Epsilon =  0.538618068873705 , and episode is : 889
# Exploring
# Epsilon =  0.5381389120488228 , and episode is : 890
# Exploring
# Exploring
# Epsilon =  0.5376596438238883 , and episode is : 891
# Exploring
# Epsilon =  0.5371802652562239 , and episode is : 892
# Epsilon =  0.5367007774025406 , and episode is : 893
# Epsilon =  0.5362211813189347 , and episode is : 894
# Exploring
# Exploring
# Epsilon =  0.5357414780608835 , and episode is : 895
# Exploring
# Exploring
# Epsilon =  0.535261668683242 , and episode is : 896
# Exploring
# Epsilon =  0.5347817542402394 , and episode is : 897
# Exploring
# Epsilon =  0.5343017357854752 , and episode is : 898
# Exploring
# Exploring
# Epsilon =  0.5338216143719158 , and episode is : 899
# Epsilon =  0.5333413910518902 , and episode is : 900
# Epsilon =  0.5328610668770871 , and episode is : 901
# Exploring
# Epsilon =  0.5323806428985511 , and episode is : 902
# Epsilon =  0.5319001201666791 , and episode is : 903
# Epsilon =  0.5314194997312162 , and episode is : 904
# Exploring
# Epsilon =  0.5309387826412526 , and episode is : 905
# Exploring
# Epsilon =  0.53045796994522 , and episode is : 906
# Exploring
# Epsilon =  0.5299770626908876 , and episode is : 907
# Exploring
# Epsilon =  0.5294960619253591 , and episode is : 908
# Exploring
# Epsilon =  0.5290149686950687 , and episode is : 909
# Exploring
# Epsilon =  0.5285337840457773 , and episode is : 910
# Exploring
# Epsilon =  0.5280525090225697 , and episode is : 911
# Exploring
# Epsilon =  0.5275711446698503 , and episode is : 912
# Exploring
# Exploring
# Epsilon =  0.5270896920313399 , and episode is : 913
# Exploring
# Epsilon =  0.5266081521500721 , and episode is : 914
# Exploring
# Epsilon =  0.5261265260683896 , and episode is : 915
# Exploring
# Epsilon =  0.525644814827941 , and episode is : 916
# Exploring
# Epsilon =  0.5251630194696769 , and episode is : 917
# Exploring
# Epsilon =  0.5246811410338467 , and episode is : 918
# Epsilon =  0.5241991805599947 , and episode is : 919
# Epsilon =  0.523717139086957 , and episode is : 920
# Epsilon =  0.523235017652858 , and episode is : 921
# Exploring
# Exploring
# Epsilon =  0.5227528172951061 , and episode is : 922
# Exploring
# Epsilon =  0.5222705390503916 , and episode is : 923
# Exploring
# Exploring
# Epsilon =  0.5217881839546819 , and episode is : 924
# Exploring
# Exploring
# Epsilon =  0.5213057530432187 , and episode is : 925
# Exploring
# Exploring
# Epsilon =  0.5208232473505144 , and episode is : 926
# Exploring
# Exploring
# Epsilon =  0.5203406679103489 , and episode is : 927
# Exploring
# Epsilon =  0.5198580157557655 , and episode is : 928
# Exploring
# Epsilon =  0.5193752919190681 , and episode is : 929
# Epsilon =  0.5188924974318173 , and episode is : 930
# Exploring
# Epsilon =  0.5184096333248275 , and episode is : 931
# Epsilon =  0.5179267006281627 , and episode is : 932
# Epsilon =  0.5174437003711337 , and episode is : 933
# Exploring
# Epsilon =  0.5169606335822947 , and episode is : 934
# Exploring
# Epsilon =  0.5164775012894394 , and episode is : 935
# Exploring
# Epsilon =  0.5159943045195979 , and episode is : 936
# Exploring
# Exploring
# Epsilon =  0.5155110442990337 , and episode is : 937
# Exploring
# Epsilon =  0.5150277216532395 , and episode is : 938
# Exploring
# Epsilon =  0.5145443376069344 , and episode is : 939
# Exploring
# Exploring
# Epsilon =  0.5140608931840603 , and episode is : 940
# Epsilon =  0.5135773894077786 , and episode is : 941
# Epsilon =  0.513093827300467 , and episode is : 942
# Exploring
# Epsilon =  0.5126102078837159 , and episode is : 943
# Exploring
# Epsilon =  0.512126532178325 , and episode is : 944
# Exploring
# Exploring
# Epsilon =  0.5116428012043004 , and episode is : 945
# Exploring
# Exploring
# Epsilon =  0.5111590159808508 , and episode is : 946
# Epsilon =  0.5106751775263844 , and episode is : 947
# Exploring
# Exploring
# Epsilon =  0.5101912868585055 , and episode is : 948
# Exploring
# Epsilon =  0.5097073449940113 , and episode is : 949
# Exploring
# Epsilon =  0.5092233529488887 , and episode is : 950
# Epsilon =  0.5087393117383106 , and episode is : 951
# Exploring
# Epsilon =  0.5082552223766328 , and episode is : 952
# Exploring
# Exploring
# Epsilon =  0.5077710858773912 , and episode is : 953
# Exploring
# Exploring
# Epsilon =  0.5072869032532977 , and episode is : 954
# Epsilon =  0.5068026755162376 , and episode is : 955
# Exploring
# Epsilon =  0.5063184036772659 , and episode is : 956
# Exploring
# Epsilon =  0.5058340887466043 , and episode is : 957
# Epsilon =  0.5053497317336381 , and episode is : 958
# Epsilon =  0.5048653336469123 , and episode is : 959
# Epsilon =  0.5043808954941295 , and episode is : 960
# Epsilon =  0.5038964182821454 , and episode is : 961
# Exploring
# Exploring
# Epsilon =  0.5034119030169665 , and episode is : 962
# Exploring
# Epsilon =  0.5029273507037465 , and episode is : 963
# Epsilon =  0.5024427623467833 , and episode is : 964
# Exploring
# Epsilon =  0.5019581389495157 , and episode is : 965
# Exploring
# Epsilon =  0.50147348151452 , and episode is : 966
# Exploring
# Epsilon =  0.5009887910435072 , and episode is : 967
# Exploring
# Epsilon =  0.5005040685373199 , and episode is : 968
# Exploring
# Epsilon =  0.5000193149959284 , and episode is : 969
# Exploring
# Epsilon =  0.4995345314184285 , and episode is : 970
# Exploring
# Epsilon =  0.4990497188030378 , and episode is : 971
# Epsilon =  0.4985648781470925 , and episode is : 972
# Epsilon =  0.49808001044704464 , and episode is : 973
# Exploring
# Epsilon =  0.49759511669845874 , and episode is : 974
# Exploring
# Epsilon =  0.4971101978960086 , and episode is : 975
# Exploring
# Exploring
# Epsilon =  0.4966252550334744 , and episode is : 976
# Epsilon =  0.4961402891037395 , and episode is : 977
# Exploring
# Epsilon =  0.49565530109878736 , and episode is : 978
# Exploring
# Exploring
# Epsilon =  0.4951702920096985 , and episode is : 979
# Exploring
# Exploring
# Epsilon =  0.4946852628266472 , and episode is : 980
# Exploring
# Epsilon =  0.49420021453889873 , and episode is : 981
# Epsilon =  0.49371514813480605 , and episode is : 982
# Exploring
# Epsilon =  0.4932300646018069 , and episode is : 983
# Exploring
# Exploring
# Epsilon =  0.4927449649264207 , and episode is : 984
# Epsilon =  0.4922598500942456 , and episode is : 985
# Exploring
# Exploring
# Epsilon =  0.4917747210899552 , and episode is : 986
# Exploring
# Epsilon =  0.4912895788972957 , and episode is : 987
# Exploring
# Epsilon =  0.4908044244990829 , and episode is : 988
# Exploring
# Exploring
# Epsilon =  0.49031925887719924 , and episode is : 989
# Exploring
# Exploring
# Epsilon =  0.4898340830125905 , and episode is : 990
# Exploring
# Exploring
# Epsilon =  0.4893488978852632 , and episode is : 991
# Exploring
# Exploring
# Epsilon =  0.4888637044742813 , and episode is : 992
# Epsilon =  0.48837850375776337 , and episode is : 993
# Exploring
# Exploring
# Epsilon =  0.4878932967128796 , and episode is : 994
# Exploring
# Epsilon =  0.48740808431584887 , and episode is : 995
# Exploring
# Epsilon =  0.4869228675419356 , and episode is : 996
# Exploring
# Epsilon =  0.486437647365447 , and episode is : 997
# Exploring
# Epsilon =  0.48595242475973016 , and episode is : 998
# Epsilon =  0.4854672006971689 , and episode is : 999
# Exploring
# Exploring
# Epsilon =  0.48498197614918115 , and episode is : 1000
# Exploring

# %%
# Convert cooperation tracking to DataFrame
track_cooperation_df = pd.DataFrame(track_cooperation)

# %%
# Print Q-tables
print("Q-Table for Player A:")
print(Q_A)
print("\nQ-Table for Player B:")
print(Q_B)
# Out:
# Q-Table for Player A:
# [[47.99933755  9.        ]
#  [49.99934364 10.        ]]
#
# Q-Table for Player B:
# [[47.99863856  9.        ]
#  [49.99887489 10.        ]]

# %%
# Plot cooperation rates
plt.figure(figsize=(10, 6))
plt.ylim(0, 1.1)
plt.plot(track_cooperation_df["episode"], track_cooperation_df["cooperation_A"], label="Player A", color="blue")
plt.plot(track_cooperation_df["episode"], track_cooperation_df["cooperation_B"], label="Player B", color="red")
plt.title("Evolution of Cooperation in the Prisoner's Dilemma")
plt.xlabel("Episode")
plt.ylabel("Cooperation Rate")
plt.legend()
plt.grid(True)
plt.show()

# %%
A=np.array([[ 1.,  2.],
       [ 3.,  4.]])
print(A)
# Out:
# [[1. 2.]
#  [3. 4.]]

# %%
print(A[:, 0])
print(A[:, 1])
print(A[1, 1])
# Out:
# [1. 3.]
# [2. 4.]
# 4.0

# %%
print(epsilon)
# Out:
# 0.8
